# %% [markdown]
# <a href="https://colab.research.google.com/github/Nunnaphanindra/Library-Managment-System/blob/master/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Basic Plot Types***
#
# ✅ Goal: Learn core visualization types.
#
# Line plots → plt.plot()
#
# Bar charts → plt.bar(), horizontal plt.barh()
#
# Scatter plots → plt.scatter()
#
# Histograms → plt.hist()
#
# Pie charts → plt.pie()
#
# Stacked plots → multiple datasets in one chart
#
# 📌 Milestone: Choose correct plot type for a given dataset.

# %% [markdown]
# **1. Line Plot → plt.plot()**
#
# 👉 Used to show trends over time or continuous data.

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[5,6,7,8]
plt.plot(x,y,marker='o',color='k',label="y=2x")
plt.title("Line Plot Example")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.show()

# %% [markdown]
# ***2. Bar Chart → plt.bar(), Horizontal → plt.barh()***
#
# 👉 Used to compare categorical data.

# %%
fruits=[ "lemon","mango","watermelon"]
values=[10,15,20]
plt.bar(fruits,values,color="green")
plt.title("Bar Chart Example")
plt.show()

# Horizontal bar chart
plt.barh(fruits, values, color="orange")
plt.title("Horizontal Bar Chart Example")
plt.show()

# %% [markdown]
# 3. Scatter Plot → plt.scatter()
#
# 👉 Used to show relationships/correlations between two variables.

# %%
import numpy as np

# Random data
x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x, y, color="red", marker="*")
plt.title("Scatter Plot Example")
plt.xlabel("X-values")
plt.ylabel("Y-values")
plt.show()

# %% [markdown]
# 4. Histogram → plt.hist()
#
# 👉 Used to show the distribution of data (frequency of values).

# %%
data = np.random.randn(1000)

plt.hist(data, bins=20, color="purple", edgecolor="black")
plt.title("Histogram Example")
plt.xlabel("Value Range")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 5. Pie Chart → plt.pie()
#
# 👉 Used to show parts of a whole (percentages).

# %%
sizes=[15,25,35,40,45]
labels=["A","B","C","D","E"]
colors=["red","blue","green","orange","black"]
plt.pie(sizes,labels=labels,colors=colors,autopct="%1.1f%%",startangle=90)
plt.title("pie chart example")
plt.show()

# %% [markdown]
# 6. Stacked Plots (Multiple datasets in one chart)
#
# 👉 Useful for showing comparison of multiple series in one plot.

# %%
x = [1, 2, 3, 4, 5]
y1 = [1, 2, 4, 8, 16]
y2 = [1, 3, 6, 10, 15]

plt.plot(x, y1, label="Series 1")
plt.plot(x, y2, label="Series 2")
plt.title("Multiple Line Plot Example")
plt.legend()
plt.show()

# %% [markdown]
# (b) Stacked Bar Plot

# %%
import numpy as np

categories = ["A", "B", "C"]
values1 = [3, 5, 7]
values2 = [2, 4, 6]

plt.bar(categories, values1, label="Group 1")
plt.bar(categories, values2, bottom=values1, label="Group 2")  # stacked
plt.title("Stacked Bar Chart Example")
plt.legend()
plt.show()

# %% [markdown]
# ***Milestone Achievement:***
#
# Line Plot → best for trends over time.
#
# Bar Chart → best for comparing categories.
#
# Scatter Plot → best for relationships.
#
# Histogram → best for data distribution.
#
# Pie Chart → best for parts of a whole.
#
# Stacked Plot → best for comparing multiple datasets.

# %% [markdown]
# ***4. Customization***
#
# ✅ Goal: Make plots readable and publication-ready.
#
# Titles, labels → plt.title(), plt.xlabel(), plt.ylabel()
#
# Legends → plt.legend()
#
# Grid lines → plt.grid()
#
# Axis limits & ticks → plt.xlim(), plt.ylim(), plt.xticks(), plt.yticks()
#
# Colors & markers → color=, marker=, linestyle=
#
# Line width, transparency → linewidth=, alpha=
#
# 📌 Milestone: Recreate a chart from a textbook or blog with custom styles.

# %% [markdown]
# 1. Titles & Labels → plt.title(), plt.xlabel(), plt.ylabel()
#
# 👉 Used to describe the chart and axes.

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[5,6,7,8]
plt.title("line plot")
plt.xlabel("x values")
plt.ylabel("y values")
plt.plot(x,y)
plt.show()

# %% [markdown]
# 2. Legends → plt.legend()
#
# 👉 Used when plotting multiple datasets.

# %%
plt.plot(x, y, label="y = 2x", color="blue")
plt.plot(x, [i**2 for i in x], label="y = x^2", color="red")
plt.title("Legend Example")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# 3. Grid Lines → plt.grid()
#
# 👉 Makes reading values easier.

# %%
plt.plot(x,y,marker='o')
plt.title("Grid line")
plt.grid(True,linestyle="--",color="grey",alpha=0.7)
plt.show()

# %% [markdown]
# 4. Axis Limits & Ticks → plt.xlim(), plt.ylim(), plt.xticks(), plt.yticks()
#
# 👉 Control the scale and tick marks.

# %%
plt.plot(x,y,marker='s',color="blue")
plt.title("axis limit and tick")
plt.xlim(0,6)
plt.ylim(0,12)
plt.xticks([0,2,4,6])
plt.yticks([0,5,10])
plt.show()

# %% [markdown]
# ✅ Output: Axis ranges restricted with custom ticks.

# %% [markdown]
# 5. Colors, Markers, Linestyle → color=, marker=, linestyle=
#
# 👉 Change how the line and points look.

# %%
plt.plot(x, y, color="green", marker="o", linestyle="--")
plt.title("Colors, Markers, Linestyle Example")
plt.show()

# %% [markdown]
# 6. Line Width & Transparency → linewidth=, alpha=
#
# 👉 Adjust line thickness and transparency.

# %%
plt.plot(x, y, color="red", linewidth=3, alpha=0.6, marker="^")
plt.title("Line Width & Transparency Example")
plt.show()

# %% [markdown]
# **Milestone Recap:**
# **You can now style your plots like in books/blogs:**
#
# Add titles/labels for clarity.
#
# Use legends to distinguish lines.
#
# Add grid lines for readability.
#
# Adjust axis/ticks for focus.
#
# Use colors, markers, linestyles for styling.
#
# Control line width & transparency for aesthetics.

# %% [markdown]
# **5. Object-Oriented Interface**
#
# ✅ Goal: Learn to use Figure and Axes.
#
# fig, ax = plt.subplots()
#
# Multiple plots: ax.plot(), ax.bar(), etc.
#
# Adding multiple subplots: plt.subplots(nrows, ncols)
#
# Adjusting layouts: plt.tight_layout()
#
# 📌 Milestone: Build a dashboard-like figure with 4–6 subplots.

# %% [markdown]
# **1. fig, ax = plt.subplots()**:
#
# 👉 Creates a Figure (fig) and an Axes (ax) object.
#
# Figure = entire canvas
#
# Axes = single plot area

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
x=[1,2,3,4]
y=[5,6,7,8]
ax.plot(x, y, marker="o", color="blue")
ax.set_title("fig,ax line plot")
ax.set_xlabel("x values")
ax.set_ylabel("y values")
plt.show()

# %% [markdown]
# 2. Multiple plots with same Axes → ax.plot(), ax.bar(), etc.
#
# 👉 You can call different methods on the same ax.

# %%
fig,ax=plt.subplots()
x=[1,2,3,4]
y1=[5,6,7,8]
y2=[9,10,11,12]
ax.plot(x,y1,label="y1=x^2",color="red")
ax.bar(x,y2,alpha=0.5,label="bar values")
ax.set_title("multiple plots")
ax.legend()
plt.show()

# %% [markdown]
#  3. Multiple Subplots → plt.subplots(nrows, ncols)
#
# 👉 Arrange multiple Axes in a grid layout.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,10,100)
y=np.sin(x)
fig,axes=plt.subplots(2,2,figsize=(8,6))
axes[0, 0].plot(x, y)
axes[0, 0].set_title("Sine Wave")
axes[0,1].scatter(np.random.rand(50),np.random.rand(50),color="red")
axes[0,1].set_title("scatter plot")
axes[1,0].bar(["A","B","C"],[3,5,7],color="orange")
axes[1,0].set_title("bar chart")
axes[1,1].hist(np.random.rand(200),bins=20,color="green")
axes[1,1].set_title("hist")
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Adjusting Layouts → plt.tight_layout()
#
# 👉 Prevents overlapping titles/labels when you have many subplots.
#
# Example above already used it.
# Without plt.tight_layout(), the axis labels/titles might overlap.

# %% [markdown]
# 📌 Milestone: Dashboard with 4–6 Subplots

# %%
fig,axes=plt.subplots(2,3,figsize=(12,6))
axes[0,0].plot(x,y,color="blue")
axes[0,0].set_title("line plot")
axes[0,1].scatter(np.random.rand(50),np.random.rand(50),color="black")
axes[0,1].set_title("scatter plot")
axes[0,2].bar(["A","B","C"],[3,5,7],color="pink")
axes[0,2].set_title("bar chart")
axes[1, 0].hist(np.random.randn(100), bins=10, color="purple")
axes[1, 0].set_title("Histogram")
axes[1, 1].pie([30,20,50], labels=["X","Y","Z"], autopct="%.1f%%")
axes[1, 1].set_title("Pie Chart")
axes[1, 2].plot(x, np.sin(x), label="sin")
axes[1, 2].plot(x, np.cos(x), label="cos")
axes[1, 2].legend()
axes[1, 2].set_title("sin & cos")

plt.tight_layout()
plt.show()

# %% [markdown]
# ***✅ Output: A dashboard-like figure with 6 different plots in one window.***

# %% [markdown]
# 6. Intermediate Topics
#
# ✅ Goal: Handle more control & data visualization.
#
# Annotations & text → ax.annotate(), ax.text()
#
# Error bars → plt.errorbar()
#
# Multiple axes → twinx(), secondary axes
#
# Logarithmic scale → ax.set_xscale("log")
#
# Custom ticks & formatting → FuncFormatter
#
# 📌 Milestone: Make a scientific plot with error bars, labels, and annotations.

# %% [markdown]
# ***1. Annotations & Text → ax.annotate(), ax.text()***
#
# 👉 Add notes, arrows, or labels inside the chart.
#
# ***In Matplotlib, annotations & text let you put extra information (like labels, arrows, notes) directly inside your plot.***

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(0,10,100)
y=np.sin(x)
fig,ax=plt.subplots()
ax.plot(x,y,label="sin(x)")
ax.text(2,0.5,"peak here",fontsize=10,color="red")
ax.annotate("zero crossing",xy=(3.14,0),xytext=(4,0.5),arrowprops=dict(facecolor="black",arrowstyle="->"))
ax.set_title("annotation example")
ax.legend()
plt.show()

# %% [markdown]
# 2. Error Bars → plt.errorbar()
#
# 👉 Show uncertainty or variability in data points.

# %%
x = np.arange(1, 6)
y = [2, 4, 6, 8, 10]
errors = [0.5, 0.7, 0.3, 0.9, 0.4]
plt.errorbar(x,y,yerr=errors,fmt='o',capsize=5,color="blue")
plt.title("error bar")
plt.show()

# %% [markdown]
# 3. Multiple Axes → twinx(), Secondary Axes
#
# 👉 Show two different scales in the same plot.

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.exp(0.1 * x)

fig, ax1 = plt.subplots()

ax1.plot(x, y1, color="blue", label="sin(x)")
ax1.set_ylabel("sin(x)", color="blue")
ax2 = ax1.twinx()
ax2.plot(x, y2, color="red", label="exp(0.1x)")
ax2.set_ylabel("exp(0.1x)", color="red")
plt.title("Multiple Axes Example")
plt.show()

# %% [markdown]
# 4. Logarithmic Scale → ax.set_xscale("log")
#
# 👉 Useful when data spans orders of magnitude.

# %%
x = np.logspace(0.1, 2, 100)  # 10^0.1 to 10^2
y = x**2

fig, ax = plt.subplots()
ax.plot(x, y, color="green")
ax.set_xscale("log")  # log scale on x-axis
ax.set_yscale("log")  # log scale on y-axis
ax.set_title("Logarithmic Scale Example")
plt.show()

# %% [markdown]
# 5. Custom Ticks & Formatting → FuncFormatter
#
# 👉 Control how ticks look (e.g., percentages, currency)

# %%
from matplotlib.ticker import FuncFormatter
x = [1, 2, 3, 4, 5]
y = [0.1, 0.25, 0.5, 0.75, 1.0]
fig, ax = plt.subplots()
ax.plot(x, y, marker="o")
formatter=FuncFormatter(lambda val,pos:f"{val*100:.0f}%")
ax.yaxis.set_major_formatter(formatter)
ax.set_title("Custom Tick Formatting Example")
plt.show()

# %% [markdown]
# 7. Styling & Themes ✅
# Goal: Improve aesthetics.
# Stylesheets → plt.style.use("ggplot"),"seaborn", "fivethirtyeight"
# Customizing rcParams → plt.rcParams["figure.figsize"] = (8,6)
# Colormaps → plt.cm.viridis, cmap= argument
# Saving figures → plt.savefig("plot.png", dpi=300)

# %% [markdown]
# *** Styling & Themes:***
# 1. Stylesheets → plt.style.use()
#
# 👉 Matplotlib comes with built-in themes (similar to filters).
# Popular: "ggplot", "seaborn", "fivethirtyeight", "dark_background".

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

# Apply ggplot style
plt.style.use("ggplot")
plt.plot(x, y, label="sin(x)")
plt.title("Style: ggplot")
plt.legend()
plt.show()

# Apply fivethirtyeight style
plt.style.use("fivethirtyeight")
plt.plot(x, y, label="sin(x)")
plt.title("Style: fivethirtyeight")
plt.legend()
plt.show()

# %% [markdown]
# **all styles at once:**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

styles = ["ggplot", "seaborn-v0_8-bright", "fivethirtyeight", "dark_background"]

for style in styles:
    plt.style.use(style)           # Apply the style
    plt.plot(x, y, label="sin(x)")
    plt.title(f"Style: {style}")   # Show which style is used
    plt.legend()
    plt.show()

# %% [markdown]
# 2. Customizing rcParams → plt.rcParams
#
# 👉 rcParams = global configuration dictionary.
# You can control figure size, font size, line width, etc.

# %%
plt.rcParams["figure.figsize"]=(8,6)
plt.rcParams["font.size"]=12
plt.rcParams["lines.linewidth"]=3
x = np.linspace(0, 5, 50)
y = np.exp(x)
plt.plot(x, y, color="purple", label="exp(x)")
plt.title("Custom rcParams Example")
plt.legend()
plt.show()

# %% [markdown]
# 3. Colormaps → plt.cm + cmap= argument
#
# 👉 Useful for gradients or mapping values to colors (heatmaps, scatter plots).

# %%
x = np.random.rand(100)
y = np.random.rand(100)
colors = np.random.rand(100)
plt.scatter(x,y,c=colors,cmap=plt.cm.viridis,s=80)
plt.colorbar(label="color scale")
plt.title("Colormap Example (viridis)")
plt.show()

# %% [markdown]
# 4. Saving Figures → plt.savefig()
#
# 👉 Save plots in different formats (PNG, PDF, SVG) with high resolution.

# %%
x = np.linspace(0, 10, 100)
y = np.cos(x)

plt.plot(x, y, color="teal", label="cos(x)")
plt.title("Saving Figures Example")
plt.legend()

# Save as PNG (300 dpi = high quality for publications)
plt.savefig("cosine_plot.png", dpi=300)

plt.show()

# %% [markdown]
# ***Advanced Plots:***

# %% [markdown]
# ***1. Heatmaps → imshow()***
#
# 👉 Represent 2D data as a color grid.

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.rand(6, 6)
plt.imshow(data,cmap="viridis",interpolation="nearest")
plt.colorbar(label="Value")
plt.title("Heatmap Example")
plt.show()

# %% [markdown]
# 2. Contour Plots → contour(), contourf()
#
# 👉 Show curves of equal value in 2D functions (like topographic maps)

# %%
x=np.linspace(-3,3,100)
y=np.linspace(-3,3,100)
x,y=np.meshgrid(x,y)
z=np.sin(np.sqrt(x**2 +y**2))
plt.contour(x,y,z,levels=10,color="blue")     #levels=10 → divide Z-values into 10 equally spaced levels
plt.contourf(x,y,z,levels=10,cmap="viridis")
plt.colorbar(label="vaues")
plt.title("contour plot")
plt.show()
# Out:
# /tmp/ipython-input-205318743.py:5: UserWarning: The following kwargs were not used by contour: 'color'
#   plt.contour(x,y,z,levels=10,color="blue")     #levels=10 → divide Z-values into 10 equally spaced levels

# %% [markdown]
# Integration with Pandas
#
# ✅ Goal: Use Matplotlib effectively with DataFrames.
#
# df.plot(kind="line", ...)
#
# Overlays with multiple columns
#
# Time series plots
#
# Histogram from DataFrame

# %% [markdown]
# Integration with Pandas

# %% [markdown]
# 1. Line Plots → df.plot(kind="line")
#
# 👉 Best for trends across time/index.

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May"],
    "Sales": [200, 250, 300, 280, 320]
}
df = pd.DataFrame(data)
df.set_index("Month", inplace=True)
df.plot(kind="line", marker="o", title="Monthly Sales")
plt.ylabel("Sales Amount")
plt.show()

# %% [markdown]
# 2. Overlays with Multiple Columns
#
# 👉 Plot multiple columns on the same chart.

# %%
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May"],
    "Sales": [200, 250, 300, 280, 320],
    "Expenses": [150, 180, 210, 200, 230]
}
df = pd.DataFrame(data)
df.set_index("Month", inplace=True)
df.plot(kind="line", marker="o", title="Sales vs Expenses")
plt.ylabel("Amount")
plt.show()

# %% [markdown]
# 3. Time Series Plots
#
# 👉 Pandas automatically handles dates as x-axis

# %%
import numpy as np
dates=pd.date_range("2023-01-01",periods=10)
df = pd.DataFrame({
    "Date": dates,
    "Temperature": np.random.randint(20, 35, size=10)
})
df.set_index("Date",inplace=True)
df.plot(title="Daily Temperature")
plt.ylabel("Temperature (°C)")
plt.show()

# %% [markdown]
# 4. Histogram from DataFrame
#
# 👉 Show distribution of values from a column.

# %%
df["Temperature"].plot(kind="hist",bins=5,color="pink",edgecolor="green")
plt.title("Temperature Distribution")
plt.xlabel("Temperature (°C)")
plt.show()

# %% [markdown]
# Milestone Recap
#
# **Line Plot → quick trend visualization.**
#
# **Overlay → multiple columns on same chart.**
#
# **Time Series → automatic handling of dates.**
#
# **Histogram → distributions from DataFrame columns**
